# %% [markdown]
# #Momento de Retroalimentación: Módulo 2 Implementación de un modelo de deep learning. (Portafolio Implementación)

# %% [markdown]
# ## Introducción
# En este notebook se realizará un modelo de clasificación de imágenes por medio de un dataset que contempla una separación de animales, entre gatos y perros, se tomará en cuenta a su vez un modelo previamente fabricado por las personas de tensorflow para poder realizar una comparativa con un modelo hecho desde 0

# %% [markdown]
# ## **Instalación de librerías**

# %%
# !pip install tensorflow-gpu==2.0.0-beta0
# !pip install tensorflow_hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement tensorflow-gpu==2.0.0-beta0 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.2.3, 2.3.0, 2.3.1, 2.3.2, 2.3.3, 2.3.4, 2.4.0, 2.4.1, 2.4.2, 2.4.3, 2.4.4, 2.5.0, 2.5.1, 2.5.2, 2.5.3, 2.6.0, 2.6.1, 2.6.2, 2.6.3, 2.6.4, 2.6.5, 2.7.0rc0, 2.7.0rc1, 2.7.0, 2.7.1, 2.7.2, 2.7.3, 2.7.4, 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0)
# ERROR: No matching distribution found for tensorflow-gpu==2.0.0-beta0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_hub in /usr/local/lib/python3.8/dist-packages (0.12.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow_hub) (3.19.6)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow_hub) (1.21.6)

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import matplotlib.pylab as plt
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np

# %% [markdown]
# Tambien utilizaremos pandas para poder tener una mejor visualización de los datos.

# %%
import pandas as pd

# Increase precision of presented data for better side-by-side comparison
pd.set_option("display.precision", 8)

# %% [markdown]
# ## **Preparación del Dataset**

# %% [markdown]
# Conectamos nuestro notebook para extraer las imagenes de nuestro drive, con la finalidad de no tener que resubir las imagenes cada vez que se utilizán

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Entramos al folder que contiene todos nuestros archivos para entrenamiento y test

# %%
# %cd drive/MyDrive/DogsVSCat
# Out:
# /content/drive/MyDrive/DogsVSCat

# %%
# !ls
# Out:
# saved_models  test  train

# %%
#!unzip train

# %%
#!unzip test

# %%
#%cd ..

# %% [markdown]
# Definimos el path hacía nuestros datos de entrenamiento

# %%
data_root='/content/drive/My Drive/DogsVSCat/train';

# %% [markdown]
# Hacemos un datagenerator con la función de tensor flow de keras, en el cúal tambien definiremos el tamaño de nuestra imagen y separaremos los distintos subsets que se estarán utilizando, en este caso el de train y validación

# %%
IMAGE_SHAPE = (224, 224)
TRAINING_DATA_DIR = str(data_root)
print(TRAINING_DATA_DIR);
datagen_kwargs = dict(rescale=1./255, validation_split=.30)
valid_datagen = tf.keras.preprocessing.image.ImageDataGenerator(**datagen_kwargs)
valid_generator = valid_datagen.flow_from_directory(
    TRAINING_DATA_DIR, 
    subset="validation", 
    shuffle=True,
    target_size=IMAGE_SHAPE
)

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(**datagen_kwargs)
train_generator = train_datagen.flow_from_directory(
    TRAINING_DATA_DIR, 
    subset="training", 
    shuffle=True,
    target_size=IMAGE_SHAPE)
# Out:
# /content/drive/My Drive/DogsVSCat/train
# Found 214 images belonging to 2 classes.
# Found 502 images belonging to 2 classes.

# %% [markdown]
# Revisamos que nuestros subsets se generen de forma adecuada, así como las etiquetas que recibirán estos

# %%
image_batch_train, label_batch_train = next(iter(train_generator))
print("Image batch shape: ", image_batch_train.shape)
print("Label batch shape: ", label_batch_train.shape)
dataset_labels = sorted(train_generator.class_indices.items(), key=lambda pair:pair[1])
dataset_labels = np.array([key.title() for key, value in dataset_labels])
print(dataset_labels)
# Out:
# Image batch shape:  (32, 224, 224, 3)
# Label batch shape:  (32, 2)
# ['Gatos' 'Perros']

# %% [markdown]
# # Training

# %% [markdown]
# Utilizaremos un modelo pre fabricado a manera de transfer learning, el modelo será el MobileNet v2 model el cúal se encuentra en el TensorFlow Hub.
#
# y cuenta con las siguientes especificaciones:
#
# *   Input shape: 224x224x3 (224x224 pixels, 3 chanels each, RGB format),
# *   Each channel has value in range [0, 1]
#
# For more details check feature vector page: https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4

# %%
model = tf.keras.Sequential([
  hub.KerasLayer("https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4", 
                 output_shape=[1280],
                 trainable=False),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(train_generator.num_classes, activation='softmax')
])
model.build([None, 224, 224, 3])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 1280)              2257984
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 2)                 2562
#
# =================================================================
# Total params: 2,260,546
# Trainable params: 2,562
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# Compilamos el modelo, con la función de perdida de "categorical_crossentropy", el optimizador "Adam" y las métricas

# %%
model.compile(
  optimizer=tf.keras.optimizers.Adam(),
  loss='categorical_crossentropy',
  metrics=['accuracy'])

# %% [markdown]
# *Entrenamos el modelo*
#
# En esta ocasión utilizaremos 10 epocas, pondremos el set de validación para que nos indique las métricas necesarias

# %%
steps_per_epoch = np.ceil(train_generator.samples/train_generator.batch_size)
val_steps_per_epoch = np.ceil(valid_generator.samples/valid_generator.batch_size)

hist = model.fit(
    train_generator, 
    epochs=10,
    verbose=1,
    steps_per_epoch=steps_per_epoch,
    validation_data=valid_generator,
    validation_steps=val_steps_per_epoch).history
# Out:
# Epoch 1/10
# 16/16 [==============================] - 16s 292ms/step - loss: 0.5090 - accuracy: 0.7610 - val_loss: 0.1413 - val_accuracy: 0.9626
# Epoch 2/10
# 16/16 [==============================] - 4s 237ms/step - loss: 0.1847 - accuracy: 0.9442 - val_loss: 0.0783 - val_accuracy: 0.9766
# Epoch 3/10
# 16/16 [==============================] - 4s 237ms/step - loss: 0.1079 - accuracy: 0.9582 - val_loss: 0.0653 - val_accuracy: 0.9720
# Epoch 4/10
# 16/16 [==============================] - 4s 235ms/step - loss: 0.0940 - accuracy: 0.9622 - val_loss: 0.0586 - val_accuracy: 0.9813
# Epoch 5/10
# 16/16 [==============================] - 4s 236ms/step - loss: 0.0695 - accuracy: 0.9741 - val_loss: 0.0551 - val_accuracy: 0.9813
# Epoch 6/10
# 16/16 [==============================] - 4s 234ms/step - loss: 0.0661 - accuracy: 0.9781 - val_loss: 0.0527 - val_accuracy: 0.9813
# Epoch 7/10
# 16/16 [==============================] - 4s 236ms/step - loss: 0.0539 - accuracy: 0.9841 - val_loss: 0.0469 - val_accuracy: 0.9813
# Epoch 8/10
# 16/16 [==============================] - 4s 231ms/step - loss: 0.0445 - accuracy: 0.9861 - val_loss: 0.0491 - val_accuracy: 0.9766
# Epoch 9/10
# 16/16 [==============================] - 4s 233ms/step - loss: 0.0371 - accuracy: 0.9900 - val_loss: 0.0439 - val_accuracy: 0.9813
# Epoch 10/10
# 16/16 [==============================] - 4s 236ms/step - loss: 0.0353 - accuracy: 0.9920 - val_loss: 0.0425 - val_accuracy: 0.9813

# %% [markdown]
# Revisamos por medio de gráficas como es el desempeño de nuestro modelo, comparando la precisión con el set de validación, así como la perdida.

# %%
acc = hist['accuracy']
print(hist['accuracy'])
print(hist['val_accuracy'])
val_acc = hist['val_accuracy']

loss = hist['loss']
val_loss = hist['val_loss']

epochs_range = range(10)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [0.7609561681747437, 0.9442231059074402, 0.958167314529419, 0.9621514081954956, 0.974103569984436, 0.9780876636505127, 0.9840637445449829, 0.9860557913780212, 0.9900398254394531, 0.9920318722724915]
# [0.9626168012619019, 0.9766355156898499, 0.9719626307487488, 0.9813084006309509, 0.9813084006309509, 0.9813084006309509, 0.9813084006309509, 0.9766355156898499, 0.9813084006309509, 0.9813084006309509]

# %% [markdown]
# Como podemos apreciar las gráficas nos podemos dar cuenta, de que el training así como el set de validación tienen muy buena precisión además de poca perdida, lo que sin duda es lo que buscamos

# %%
final_loss, final_accuracy = model.evaluate(valid_generator, steps = val_steps_per_epoch)
print("Final loss: {:.2f}".format(final_loss))
print("Final accuracy: {:.2f}%".format(final_accuracy * 100))
# Out:
# 7/7 [==============================] - 1s 159ms/step - loss: 0.0425 - accuracy: 0.9813
# Final loss: 0.04
# Final accuracy: 98.13%

# %% [markdown]
# # Exportamos el modelo

# %%
ANIMAL_SAVED_MODEL = "saved_models/animal"
model.save(ANIMAL_SAVED_MODEL)

# %% [markdown]
# ## Cargamos el modelo de TensorFlow (el cual previamente guardamos)

# %%
from tensorflow import keras
# Load SavedModel

animal_model = keras.models.load_model(ANIMAL_SAVED_MODEL)

# %% [markdown]
# ## Revisamos las predicciones con el subset de validación

# %%
# Get images and labels batch from validation dataset generator

val_image_batch, val_label_batch = next(iter(valid_generator))
true_label_ids = np.argmax(val_label_batch, axis=-1)

print("Validation batch shape:", val_image_batch.shape)
# Out:
# Validation batch shape: (32, 224, 224, 3)

# %% [markdown]
# lo que nos dice el shape es que tenemos un batch de 32 imágenes, con tamaño y canales de: 224x224x3.
#
# Realizamos una predicción

# %%
tf_model_predictions = animal_model.predict(val_image_batch)
print("Prediction results shape:", tf_model_predictions.shape)
# Out:
# 1/1 [==============================] - 1s 841ms/step
# Prediction results shape: (32, 2)

# %% [markdown]
# Realizamos la conversión de las predicciones en un data frame de pandas para revisar que es lo que está sucediendo

# %%
tf_pred_dataframe = pd.DataFrame(tf_model_predictions)
tf_pred_dataframe.columns = dataset_labels

print("Prediction results for the first elements")
tf_pred_dataframe.head()
# Out:
# Prediction results for the first elements
#         Gatos      Perros
# 0  0.99977094  0.00022906
# 1  0.99936777  0.00063230
# 2  0.99785322  0.00214670
# 3  0.99972159  0.00027843
# 4  0.00061178  0.99938822

# %%
predicted_ids = np.argmax(tf_model_predictions, axis=-1)
predicted_labels = dataset_labels[predicted_ids]

# %% [markdown]
# Lo que haremos a continuación será imprimir cuales fueron nuestras predicciones con sus respectivas imágenes

# %%
plt.figure(figsize=(10,9))
plt.subplots_adjust(hspace=0.5)
for n in range(30):
  plt.subplot(6,5,n+1)
  plt.imshow(val_image_batch[n])
  color = "green" if predicted_ids[n] == true_label_ids[n] else "red"
  plt.title(predicted_labels[n].title(), color=color)
  plt.axis('off')
_ = plt.suptitle("Model predictions (Verde: correctas, Rojo: incorrectas)")

# %% [markdown]
# Para el siguiente modelo intentaremos utilizar una capa de data augmentation, con la función de keras, que nos permitirá cambiar ciertos parámetros de las imágenes, teniendo así menores sesgos en nuestro entrenamiento

# %%
data_augmentation = keras.Sequential(
  [
    tf.keras.layers.RandomFlip("horizontal",
                      input_shape=(224,
                                  224,
                                  3)),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
  ]
)

# %% [markdown]
# Probaremos con una serie de capas de convolución, así como max pooling y batch normalization, para ver los resultados de nuestro modelo, esto sin dejar de lado que utilizaremos a su vez en la capa final la función de activación de softmax para realizar la clasificación

# %%
new_model = keras.models.Sequential()

initializers = {
    
}
new_model.add( 
    keras.layers.Conv2D(
        24, 5, input_shape=(224,224,3), 
        activation='relu', 
    )
)
new_model.add( keras.layers.MaxPooling2D(2) )
new_model.add( 
    keras.layers.Conv2D(
        48, 5, activation='relu', 
    )
)
new_model.add( keras.layers.MaxPooling2D(2) )
new_model.add( 
    keras.layers.Conv2D(
        96, 5, activation='relu', 
    )
)
new_model.add( keras.layers.Flatten() )
new_model.add( keras.layers.Dropout(0.9) )

new_model.add( keras.layers.Dense(
    2, activation='softmax',
    )
)

new_model.summary()
new_model.compile(loss='binary_crossentropy',
              optimizer=keras.optimizers.Adamax(lr=0.001),
              metrics=['acc'])
callback = tf.keras.callbacks.EarlyStopping(
    monitor="loss",
    min_delta=0,
    patience=6,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_34 (Conv2D)          (None, 220, 220, 24)      1824
#
#  max_pooling2d_18 (MaxPoolin  (None, 110, 110, 24)     0
#  g2D)
#
#  conv2d_35 (Conv2D)          (None, 106, 106, 48)      28848
#
#  max_pooling2d_19 (MaxPoolin  (None, 53, 53, 48)       0
#  g2D)
#
#  conv2d_36 (Conv2D)          (None, 49, 49, 96)        115296
#
#  flatten_11 (Flatten)        (None, 230496)            0
#
#  dropout_18 (Dropout)        (None, 230496)            0
#
#  dense_17 (Dense)            (None, 2)                 460994
#
# =================================================================
# Total params: 606,962
# Trainable params: 606,962
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compilamos nuestro modelo, con optimizador adam, sparse categorical cross entropy de keras, y las métricas, además de agregar un early stopping con la finalidad de vigilar nuestro val loss, además de la recuperación de nuestros mejores pesos

# %%
''' new_model.compile(optimizer='adam',
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy']) '''
# Out:
# " new_model.compile(optimizer='adam',\n                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),\n                  metrics=['accuracy']) "

# %% [markdown]
# Entrenamos el modelo

# %%
steps_per_epoch = np.ceil(train_generator.samples/train_generator.batch_size)
val_steps_per_epoch = np.ceil(valid_generator.samples/valid_generator.batch_size)
epochs = 40

new_hist = new_model.fit(
    train_generator, 
    epochs=epochs,
    verbose=1,
    callbacks=[callback],
    steps_per_epoch=steps_per_epoch,
    validation_data=valid_generator,
    validation_steps=val_steps_per_epoch).history
# Out:
# Epoch 1/40
# 16/16 [==============================] - 5s 254ms/step - loss: 0.8774 - acc: 0.5219 - val_loss: 0.6903 - val_acc: 0.5561
# Epoch 2/40
# 16/16 [==============================] - 4s 228ms/step - loss: 0.6870 - acc: 0.5259 - val_loss: 0.6833 - val_acc: 0.5654
# Epoch 3/40
# 16/16 [==============================] - 4s 227ms/step - loss: 0.6815 - acc: 0.5737 - val_loss: 0.6850 - val_acc: 0.5467
# Epoch 4/40
# 16/16 [==============================] - 4s 227ms/step - loss: 0.6750 - acc: 0.5717 - val_loss: 0.6804 - val_acc: 0.5654
# Epoch 5/40
# 16/16 [==============================] - 4s 224ms/step - loss: 0.6585 - acc: 0.6016 - val_loss: 0.6631 - val_acc: 0.5981
# Epoch 6/40
# 16/16 [==============================] - 4s 228ms/step - loss: 0.6399 - acc: 0.6394 - val_loss: 0.6598 - val_acc: 0.5841
# Epoch 7/40
# 16/16 [==============================] - 4s 226ms/step - loss: 0.6206 - acc: 0.6653 - val_loss: 0.6513 - val_acc: 0.5654
# Epoch 8/40
# 16/16 [==============================] - 4s 227ms/step - loss: 0.6526 - acc: 0.5837 - val_loss: 0.6604 - val_acc: 0.5234
# Epoch 9/40
# 16/16 [==============================] - 4s 225ms/step - loss: 0.6217 - acc: 0.6853 - val_loss: 0.6400 - val_acc: 0.6449
# Epoch 10/40
# 16/16 [==============================] - 4s 260ms/step - loss: 0.6113 - acc: 0.6733 - val_loss: 0.6325 - val_acc: 0.6355
# Epoch 11/40
# 16/16 [==============================] - 4s 227ms/step - loss: 0.5788 - acc: 0.7171 - val_loss: 0.6215 - val_acc: 0.6402
# Epoch 12/40
# 16/16 [==============================] - 4s 249ms/step - loss: 0.5595 - acc: 0.7490 - val_loss: 0.6114 - val_acc: 0.6589
# Epoch 13/40
# 16/16 [==============================] - 4s 236ms/step - loss: 0.5615 - acc: 0.7171 - val_loss: 0.6614 - val_acc: 0.6215
# Epoch 14/40
# 16/16 [==============================] - 4s 229ms/step - loss: 0.5333 - acc: 0.7410 - val_loss: 0.6062 - val_acc: 0.6449
# Epoch 15/40
# 16/16 [==============================] - 4s 229ms/step - loss: 0.5120 - acc: 0.7390 - val_loss: 0.5980 - val_acc: 0.6729
# Epoch 16/40
# 16/16 [==============================] - 4s 232ms/step - loss: 0.4806 - acc: 0.7769 - val_loss: 0.6216 - val_acc: 0.6822
# Epoch 17/40
# 16/16 [==============================] - 4s 230ms/step - loss: 0.4826 - acc: 0.7849 - val_loss: 0.6113 - val_acc: 0.6822
# Epoch 18/40
# 16/16 [==============================] - 4s 230ms/step - loss: 0.4518 - acc: 0.7968 - val_loss: 0.6234 - val_acc: 0.6589
# Epoch 19/40
# 16/16 [==============================] - 4s 227ms/step - loss: 0.4633 - acc: 0.7928 - val_loss: 0.6049 - val_acc: 0.6822
# Epoch 20/40
# 16/16 [==============================] - 4s 232ms/step - loss: 0.4314 - acc: 0.8088 - val_loss: 0.6137 - val_acc: 0.6869
# Epoch 21/40
# 16/16 [==============================] - 4s 230ms/step - loss: 0.4111 - acc: 0.7948 - val_loss: 0.6291 - val_acc: 0.6636
# Epoch 22/40
# 16/16 [==============================] - 4s 229ms/step - loss: 0.3909 - acc: 0.8406 - val_loss: 0.6278 - val_acc: 0.6729
# Epoch 23/40
# 16/16 [==============================] - 4s 234ms/step - loss: 0.3887 - acc: 0.8267 - val_loss: 0.6227 - val_acc: 0.6916
# Epoch 24/40
# 16/16 [==============================] - 4s 226ms/step - loss: 0.3737 - acc: 0.8327 - val_loss: 0.6213 - val_acc: 0.6776
# Epoch 25/40
# 16/16 [==============================] - 4s 227ms/step - loss: 0.3575 - acc: 0.8546 - val_loss: 0.6723 - val_acc: 0.6822
# Epoch 26/40
# 16/16 [==============================] - 4s 226ms/step - loss: 0.3305 - acc: 0.8665 - val_loss: 0.6532 - val_acc: 0.6963
# Epoch 27/40
# 16/16 [==============================] - 4s 234ms/step - loss: 0.3075 - acc: 0.8785 - val_loss: 0.6671 - val_acc: 0.6869
# Epoch 28/40
# 16/16 [==============================] - 4s 227ms/step - loss: 0.3155 - acc: 0.8845 - val_loss: 0.6955 - val_acc: 0.6729
# Epoch 29/40
# 16/16 [==============================] - 4s 224ms/step - loss: 0.3192 - acc: 0.8566 - val_loss: 0.6679 - val_acc: 0.6822
# Epoch 30/40
# 16/16 [==============================] - 4s 228ms/step - loss: 0.3293 - acc: 0.8586 - val_loss: 0.6902 - val_acc: 0.6636
# Epoch 31/40
# 16/16 [==============================] - 4s 228ms/step - loss: 0.3142 - acc: 0.8765 - val_loss: 0.7011 - val_acc: 0.6636
# Epoch 32/40
# 16/16 [==============================] - 5s 334ms/step - loss: 0.2670 - acc: 0.8944 - val_loss: 0.6828 - val_acc: 0.6869
# Epoch 33/40
# 16/16 [==============================] - 4s 226ms/step - loss: 0.2323 - acc: 0.9223 - val_loss: 0.7124 - val_acc: 0.6916
# Epoch 34/40
# 16/16 [==============================] - 4s 234ms/step - loss: 0.2351 - acc: 0.9124 - val_loss: 0.7197 - val_acc: 0.7150
# Epoch 35/40
# 16/16 [==============================] - 4s 228ms/step - loss: 0.2632 - acc: 0.8924 - val_loss: 0.7289 - val_acc: 0.6822
# Epoch 36/40
# 16/16 [==============================] - 4s 224ms/step - loss: 0.2345 - acc: 0.9104 - val_loss: 0.6933 - val_acc: 0.6776
# Epoch 37/40
# 16/16 [==============================] - 4s 226ms/step - loss: 0.2152 - acc: 0.9243 - val_loss: 0.7707 - val_acc: 0.7009
# Epoch 38/40
# 16/16 [==============================] - 4s 228ms/step - loss: 0.2085 - acc: 0.9263 - val_loss: 0.7304 - val_acc: 0.6729
# Epoch 39/40
# 16/16 [==============================] - 4s 230ms/step - loss: 0.1816 - acc: 0.9323 - val_loss: 0.7620 - val_acc: 0.7103
# Epoch 40/40
# 16/16 [==============================] - 4s 230ms/step - loss: 0.1689 - acc: 0.9422 - val_loss: 0.8305 - val_acc: 0.7056

# %% [markdown]
# Imprimimos el accuracy final de nuestro modelo

# %%
final_loss, final_accuracy = new_model.evaluate(valid_generator, steps = val_steps_per_epoch)
print("Final loss: {:.2f}".format(final_loss))
print("Final accuracy: {:.2f}%".format(final_accuracy * 100))
# Out:
# 7/7 [==============================] - 1s 148ms/step - loss: 0.8305 - acc: 0.7056
# Final loss: 0.83
# Final accuracy: 70.56%

# %%
print(new_hist)
# Out:
# {'loss': [0.8773669600486755, 0.6869579553604126, 0.6815054416656494, 0.6749922037124634, 0.6585137248039246, 0.639876127243042, 0.6205912828445435, 0.652639627456665, 0.6217488050460815, 0.611306369304657, 0.5787817239761353, 0.5595059394836426, 0.5615116357803345, 0.5332757234573364, 0.5119515061378479, 0.48058807849884033, 0.4825977683067322, 0.45177391171455383, 0.46331730484962463, 0.4314305782318115, 0.41113150119781494, 0.39086467027664185, 0.38870203495025635, 0.37373262643814087, 0.35747772455215454, 0.33051925897598267, 0.30753740668296814, 0.31554216146469116, 0.31922975182533264, 0.32934415340423584, 0.3142094910144806, 0.26700329780578613, 0.23233819007873535, 0.23514196276664734, 0.2632390856742859, 0.2345024198293686, 0.21517406404018402, 0.2084745317697525, 0.1816355288028717, 0.16893234848976135], 'acc': [0.5219123363494873, 0.525896430015564, 0.5737051963806152, 0.5717131495475769, 0.6015936136245728, 0.6394422054290771, 0.6653386354446411, 0.5836653113365173, 0.6852589845657349, 0.6733067631721497, 0.717131495475769, 0.7490040063858032, 0.717131495475769, 0.7410358786582947, 0.7390438318252563, 0.7768924236297607, 0.7848605513572693, 0.7968127727508545, 0.7928286790847778, 0.8087649345397949, 0.7948207259178162, 0.8406374454498291, 0.8266932368278503, 0.8326693177223206, 0.8545816540718079, 0.8665338754653931, 0.8784860372543335, 0.8844621777534485, 0.8565737009048462, 0.8585657477378845, 0.8764940500259399, 0.8944222927093506, 0.9223107695579529, 0.912350594997406, 0.892430305480957, 0.9103585481643677, 0.9243028163909912, 0.9262948036193848, 0.9322709441184998, 0.9422310590744019], 'val_loss': [0.6903461813926697, 0.683260977268219, 0.6849735379219055, 0.6803955435752869, 0.663124144077301, 0.6598333120346069, 0.6512542366981506, 0.6603977084159851, 0.6400052905082703, 0.6324543952941895, 0.6214586496353149, 0.6114450097084045, 0.6614158153533936, 0.6061521172523499, 0.5980159640312195, 0.6215943098068237, 0.6112592220306396, 0.6233887076377869, 0.6049169301986694, 0.6137038469314575, 0.6291267275810242, 0.6278411149978638, 0.622670590877533, 0.62127685546875, 0.6722698211669922, 0.6531586050987244, 0.6670815348625183, 0.6954769492149353, 0.6679334044456482, 0.6902310252189636, 0.7010623812675476, 0.6828250885009766, 0.7124140858650208, 0.7196610569953918, 0.728858232498169, 0.6932929754257202, 0.7706813216209412, 0.7304226756095886, 0.7620376944541931, 0.8305093050003052], 'val_acc': [0.5560747385025024, 0.5654205679893494, 0.5467289686203003, 0.5654205679893494, 0.5981308221817017, 0.5841121673583984, 0.5654205679893494, 0.5233644843101501, 0.644859790802002, 0.6355140209197998, 0.6401869058609009, 0.65887850522995, 0.6214953064918518, 0.644859790802002, 0.672897219657898, 0.6822429895401001, 0.6822429895401001, 0.65887850522995, 0.6822429895401001, 0.6869158744812012, 0.663551390171051, 0.672897219657898, 0.6915887594223022, 0.677570104598999, 0.6822429895401001, 0.6962617039680481, 0.6869158744812012, 0.672897219657898, 0.6822429895401001, 0.663551390171051, 0.663551390171051, 0.6869158744812012, 0.6915887594223022, 0.7149532437324524, 0.6822429895401001, 0.677570104598999, 0.7009345889091492, 0.672897219657898, 0.7102803587913513, 0.7056074738502502]}

# %%
acc = new_hist['acc']
print(new_hist['acc'])
print(new_hist['val_acc'])
val_acc = new_hist['val_acc']

loss = new_hist['loss']
val_loss = new_hist['val_loss']

epochs_range = range(len(new_hist.get("loss")))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [0.5219123363494873, 0.525896430015564, 0.5737051963806152, 0.5717131495475769, 0.6015936136245728, 0.6394422054290771, 0.6653386354446411, 0.5836653113365173, 0.6852589845657349, 0.6733067631721497, 0.717131495475769, 0.7490040063858032, 0.717131495475769, 0.7410358786582947, 0.7390438318252563, 0.7768924236297607, 0.7848605513572693, 0.7968127727508545, 0.7928286790847778, 0.8087649345397949, 0.7948207259178162, 0.8406374454498291, 0.8266932368278503, 0.8326693177223206, 0.8545816540718079, 0.8665338754653931, 0.8784860372543335, 0.8844621777534485, 0.8565737009048462, 0.8585657477378845, 0.8764940500259399, 0.8944222927093506, 0.9223107695579529, 0.912350594997406, 0.892430305480957, 0.9103585481643677, 0.9243028163909912, 0.9262948036193848, 0.9322709441184998, 0.9422310590744019]
# [0.5560747385025024, 0.5654205679893494, 0.5467289686203003, 0.5654205679893494, 0.5981308221817017, 0.5841121673583984, 0.5654205679893494, 0.5233644843101501, 0.644859790802002, 0.6355140209197998, 0.6401869058609009, 0.65887850522995, 0.6214953064918518, 0.644859790802002, 0.672897219657898, 0.6822429895401001, 0.6822429895401001, 0.65887850522995, 0.6822429895401001, 0.6869158744812012, 0.663551390171051, 0.672897219657898, 0.6915887594223022, 0.677570104598999, 0.6822429895401001, 0.6962617039680481, 0.6869158744812012, 0.672897219657898, 0.6822429895401001, 0.663551390171051, 0.663551390171051, 0.6869158744812012, 0.6915887594223022, 0.7149532437324524, 0.6822429895401001, 0.677570104598999, 0.7009345889091492, 0.672897219657898, 0.7102803587913513, 0.7056074738502502]

# %% [markdown]
# Lo guardamos

# %%
ANIMAL_SAVED_MODEL2 = "saved_models/animal2"

# %%
new_model.save(ANIMAL_SAVED_MODEL2)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.

# %% [markdown]
# lo cargamos con la función de keras

# %%
from tensorflow import keras
# Load SavedModel

animal_model2 = keras.models.load_model(ANIMAL_SAVED_MODEL2)

# %%
tf_model_predictions = animal_model2.predict(val_image_batch)
print("Prediction results shape:", tf_model_predictions.shape)
# Out:
# 1/1 [==============================] - 0s 71ms/step
# Prediction results shape: (32, 2)

# %%
# !pwd
# Out:
# /content/drive/MyDrive/DogsVSCat

# %% [markdown]
# Colocamos las predicciones de nuestro modelo en un data frame para mejorar su visualización

# %%
tf_pred_dataframe = pd.DataFrame(tf_model_predictions)
tf_pred_dataframe.columns = dataset_labels

print("Prediction results for the first elements")
tf_pred_dataframe.head()
# Out:
# Prediction results for the first elements
#         Gatos      Perros
# 0  0.98363990  0.01636009
# 1  0.95653725  0.04346268
# 2  0.00071550  0.99928457
# 3  0.59934968  0.40065032
# 4  0.00438326  0.99561679

# %%
predicted_ids = np.argmax(tf_model_predictions, axis=-1)
predicted_labels = dataset_labels[predicted_ids]

# %% [markdown]
# Por último, colocamos las imágenes con su respectiva predicción, tanto las correctas como las incorrectas

# %%
plt.figure(figsize=(10,9))
plt.subplots_adjust(hspace=0.5)
for n in range(30):
  plt.subplot(6,5,n+1)
  plt.imshow(val_image_batch[n])
  color = "green" if predicted_ids[n] == true_label_ids[n] else "red"
  plt.title(predicted_labels[n].title(), color=color)
  plt.axis('off')
_ = plt.suptitle("Model predictions (Verde: correctas, Rojo: incorrectas)")

# %% [markdown]
# En conclusión un modelo ya previamente configurado, como el utilizado en la primera ejecución tiene muy buenos resultados, sin duda mejores que los del segundo, el cual fue construido desde 0, ya que el modelo que ha sido previamente configurado, evidentemente ya cuenta con muchos ajustes que se han ido implementando a lo largo del tiempo, haciendo que dicho modelo sea cada vez más preciso, por lo tanto esta difícil igualar el nivel de accuracy, pero a pesar de apenas tener pequeños acercamientos con modelos de deep learning, siento que al ser el primer modelo de clasificación que construyo, realmente tuvo buenos resultados, que sin duda a medida de más experiencia seguirán mejorando
